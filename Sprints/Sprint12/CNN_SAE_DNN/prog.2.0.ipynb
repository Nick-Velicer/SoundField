# %% [markdown]
# # EEG Classification of Emotions Using CNN, SAE, and DNN
#
# From the paper "EEG-Based Emotion Classification Using a Deep Neural Network and Sparse Autoencoder", they found to have incredibly high recognition accuracy for emotions using EEG data that they put through a Convolutional Recurrent Neural Network, then a Sparse Autoencoder, and finally a Deep Neural Network.
#
# Paper: https://www.frontiersin.org/articles/10.3389/fnsys.2020.00043/full
#
# DEAP Dataset: https://www.eecs.qmul.ac.uk/mmv/datasets/deap/
#
# SEED Dataset: https://bcmi.sjtu.edu.cn/home/seed/seed.html
#
# Output Labels: [-1: "negative", 0: "neutral", 1: "positive"]

# %% [markdown]
# ## Import Libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import os
from scipy.signal import butter, freqs, sosfilt
from mlxtend.preprocessing import standardize
from sklearn.model_selection import train_test_split
import scipy.io

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers, models
# Out:
# 2023-03-27 20:46:38.960624: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [markdown]
# ## Load SEED Data
#
# - 15 subjects
# - 15 sets of 80 second recordings
# - 200 Hz recording
# - 14 EEG Channels
# - (15 * 15) 225 recordings 14 * (200 * 80) 16000 matrixes
# - Negative, Neutral, and Positive are recorded for all 15 trials of each subject
#
# Input Matrix Shape: `225 x 14 x 16000`
#
# Output Matrix Shape: `225 x 3`

# %%
RECORDINGS_PATH = "/Users/michaelperry/Downloads/SEED_EEG/Preprocessed_EEG_1per/"
ext = ('.mat')

# Gather the filenames and sort them in order of experiment number
files = os.listdir(RECORDINGS_PATH)
files.sort()

# Set the recording rate of the data
HZ = 200
# Set the channel indexs of EMOTIV from 62 channel reading
channels = [3,4,5,7,11,13,15,21,23,31,41,49,58,60]

# Get the labels of trials in experiments
mat = scipy.io.loadmat(RECORDINGS_PATH + "label.mat")
# Initialize empty list to put the converted labels into
trial_labels = []
# Iterate through labels and convert to (3,1) classification vector
for l in mat['label'][0]:
    if l == -1:
        trial_labels.append(np.array([1,0,0]))
    elif l == 0:
        trial_labels.append(np.array([0,1,0]))
    elif l == 1:
        trial_labels.append(np.array([0,0,1]))

# Take the list of 1D numpy arrays and
# convert it to 2D matrix
trial_labels = np.stack(trial_labels)

# Initialize empty data and labels arrays
data = []
labels = np.array([[0,0,0]]) # Initialize the shape to stack onto
# Iterate through files in Preprocessed_EEG folder
for file in files:
    # Only look at experiment .mat files
    if file.endswith(ext) and file != "label.mat":
        # Print current file that loading
        print("Loading " + file + "...")
        # Load the .mat file into a dictionary
        mat = scipy.io.loadmat(RECORDINGS_PATH + file)
        # Iterate through all the keys in the dictionary
        for k in mat.keys():
            # Only look at the eeg trials labeled "djc_eeg##"
            if "eeg" in k:
                # Extract data for trial
                trial = mat[k]
                # Take only 80 s after the first 5 s
                # This is to normalize the lengths of trials
                trial = trial[:, 5*HZ:85*HZ]
                # Select only the needed channels
                trial = trial[channels,:]
                # Standardize 2d array
                trial = standardize(trial)
                # Append trial data to data list
                data.append(trial)

        # Append this experiments trial labels to the entire labels vector
        labels = np.vstack([labels, trial_labels])

# Take the list of 2D numpy arrays and
# convert it to 3D matrix
raw = np.stack(data)
# Delete first template row for labels
labels = np.delete(labels, 0, 0)

print("raw Shape:", raw.shape)
print("labels Shape:", labels.shape)
# Out:
# Loading 01_20131027.mat...
# Loading 02_20140404.mat...
# Loading 03_20140603.mat...
# Loading 04_20140621.mat...
# Loading 05_20140411.mat...
# Loading 06_20130712.mat...
# Loading 07_20131027.mat...
# Loading 08_20140511.mat...
# Loading 09_20140620.mat...
# Loading 10_20131130.mat...
# Loading 11_20140618.mat...
# Loading 12_20131127.mat...
# Loading 13_20140527.mat...
# Loading 14_20140601.mat...
# Loading 15_20130709.mat...
# raw Shape: (225, 14, 16000)
# labels Shape: (225, 3)

# %% [markdown]
# ## Band-Pass Filter Functions

# %%
# Functions from: https://stackoverflow.com/questions/12093594/how-to-implement-band-pass-butterworth-filter-with-scipy-signal-butterhttps://stackoverflow.com/questions/12093594/how-to-implement-band-pass-butterworth-filter-with-scipy-signal-butter
# Params from: https://docs.scipy.org/doc/scipy/reference/generated/scipy.signal.butter.html
def butter_bandpass(lowcut, highcut, fs, order=5):
    return butter(order, [lowcut, highcut], fs=fs, btype='bandpass', output='sos')

def butter_bandpass_filter(data, lowcut, highcut, fs, order=5):
    sos = butter_bandpass(lowcut, highcut, fs, order=order)
    y = sosfilt(sos, data)
    return y

# %% [markdown]
# ## General Band-Pass Filter
#
# - This is used to get rid of general noise
# - Done across the Hz range 0.1-45
#
# Input Matrix Shape: `225 x 14 x 16000`

# %%
# Filter Params
LOWCUT = 0.1
HIGHCUT = 45.0
ORDER = 9

# Bool for plotting first filter
plotData = True
# Initialize empty matrix to put all filtered data into
filterData = np.zeros_like(raw)

# Iterate through each epoch/recording
for idx in range(raw.shape[0]):
    # Get the epoch of the index
    epoch = raw[idx]
    # Initialize empty matrix to put filtered epoch data into
    filteredEpoch = np.zeros_like(epoch)

    # Iterate through the rows of the epoch/recording
    # Each row is a 1D vector of one electrodes values
    for i in range(epoch.shape[0]):
        # Get the row of the index
        channel = epoch[i]
        # Use the butterworth bandpass filter from 0.1-45 Hz
        filtered = butter_bandpass_filter(channel, LOWCUT, HIGHCUT, HZ, order=ORDER)

        # Test plotting the filtered data
        if (plotData):
            t = np.linspace(0, 80, HZ*80, False) # timesteps for 80@200Hz
            fig, (ax1, ax2) = plt.subplots(2, 1, sharex=True, figsize=(15,5))
            ax1.plot(t, channel)
            ax2.plot(t, filtered)
            plt.show()
            plotData = False
        
        # Add filtered channel into the filterEpoch matrix
        filteredEpoch[i] = filtered
    
    # Add filtered epoch into the filterData matrix
    filterData[idx] = filteredEpoch

print("filterData Shape:", filterData.shape)
# Out:
# filterData Shape: (225, 14, 16000)

# %% [markdown]
# ## Butterworth Band-Pass Filter
#
# - $\alpha$ (1-7 Hz), $\beta$ (8-13 Hz), $\theta$ (14-30 Hz), $\lambda$ (30-45 Hz)
# - This will break up the single stream of data from each channel into 4 streams of separate bands
#
# Input Matrix Shape: `225 x 4 x 14 x 16000`

# %%
# Filter Params
ALPHA = (1, 7)
BETA = (8, 13)
THETA = (14, 30)
LAMBDA = (30, 45)
ORDER = 9

# Bool for plotting first filter
plotData = True
# Initialize empty list to put all epoched band data into
bandData = []

# Iterate through each filtered epoch/recording
for idx in range(filterData.shape[0]):
    # Get the epoch of the index
    epoch = filterData[idx]
    # Initialize empty matrixs to put band data into
    alphaData = np.zeros_like(epoch)
    betaData = np.zeros_like(epoch)
    thetaData = np.zeros_like(epoch)
    lambdaData = np.zeros_like(epoch)

    # Iterate through the rows of the filtered epoch/recording
    # Each row is a 1D vector of one electrodes values
    for i in range(epoch.shape[0]):
        # Get the row of the index
        channel = epoch[i]
        # Use the butterworth bandpass filter for each band on a channel
        alphaChan = butter_bandpass_filter(channel, ALPHA[0], ALPHA[1], HZ, order=ORDER)
        betaChan = butter_bandpass_filter(channel, BETA[0], BETA[1], HZ, order=ORDER)
        thetaChan = butter_bandpass_filter(channel, THETA[0], THETA[1], HZ, order=ORDER)
        lambdaChan = butter_bandpass_filter(channel, LAMBDA[0], LAMBDA[1], HZ, order=ORDER)

        # Test plotting the filtered data
        if (plotData):
            t = np.linspace(0, 80, HZ*80, False) # timesteps for 80@200Hz
            fig, (ax1, ax2, ax3, ax4, ax5) = plt.subplots(5, 1, sharex=True, figsize=(15,10))
            ax1.plot(t, channel)
            ax2.plot(t, alphaChan)
            ax3.plot(t, betaChan)
            ax4.plot(t, thetaChan)
            ax5.plot(t, lambdaChan)
            plt.show()
            plotData = False

        # Add each band channel vector into its respective matrix
        alphaData[i] = alphaChan
        betaData[i] = betaChan
        thetaData[i] = thetaChan
        lambdaData[i] = lambdaChan
    
    # Initialize list of band data
    epochBandData = [alphaData, betaData, thetaData, lambdaData]
    # Take the list of 2D numpy arrays and
    # convert it to 3D matrix
    epochBandData = np.stack(epochBandData)
    # Append the epochBandData to bandData list
    bandData.append(epochBandData)

# Take the list of 3D numpy arrays and 
# convert it to 4D matrix
bandData = np.stack(bandData)

print("bandData Shape:", bandData.shape)
# Out:
# bandData Shape: (225, 4, 14, 16000)

# %% [markdown]
# ## Epoch the Epochs
#
# - For each trils of 80 s, 19 segments are obtained using an 8 s time window moving every 4 s.
# - This will extrapolate our training data
# - (200 * 80) => (200 * 8)
# - 16000 => 1600
# - 225 * 19 = 4275
# - Increasing our input data means we increase output
# - All 19 new samples from each apoch have the same output
#
# Input Matrix Shape: `4275 x 4 x 14 x 1600`
#
# Output Matrix Shape: `4275 x 3`

# %%
# Initialize empty lists to put all 8 seconds epochs and new labels into respectively
epochData = []
epochLabels = []

# Iterate through each filtered band epoch/recording
for idx in range(bandData.shape[0]):
    # Get the epoch of the index
    epoch = bandData[idx]
    label = labels[idx]

    # Iterrate through 8 second time intervals 
    for t in range(0, epoch.shape[2], HZ*4):
        # Break if 8 seconds goes past end of recording
        if (t + HZ*8 > epoch.shape[2]):
            break

        # Initialize empty matrix to put 8 s epoch into (4, 14, 1024)
        epoch8 = np.zeros((epoch.shape[0], epoch.shape[1], HZ*8))

        # Iterate through each band in the epoch
        for i in range(epoch.shape[0]):
            # Add the time interval from this
            # band into the epoch8 matrix
            epoch8[i] = epoch[i,:,t:t+HZ*8]

        # Append 8 second epoch to epochData list
        epochData.append(epoch8)
        # Append current label to epochLabels list
        epochLabels.append(label)

# Take the list of 3D numpy arrays and 
# convert it to 4D matrix
epochData = np.stack(epochData)
# Convert list to numpy array
epochLabels = np.array(epochLabels)

print("epochData Shape:", epochData.shape)
print("epochLabels Shape:", epochLabels.shape)
# Out:
# epochData Shape: (4275, 4, 14, 1600)
# epochLabels Shape: (4275, 3)

# %% [markdown]
# ## PCC Feature Extraction
#
# - PCC (Pearson Correlation Coefficient)
# - On every band and epoch
# - Basically calculating correlation of every channel pair against each other
# - (14 x 1600) => (14 x 14)
#
# Input Matrix Shape: `4275 x 4 x 14 x 14`

# %%
# Initialize empty list to put the PCC data into
pccData = []

print("epochData Shape:", epochData.shape)
# Iterate through each epoch
for idx in range(epochData.shape[0]):
    # Get the epoch of the index
    epoch = epochData[idx]
    # Initialize empty list to put the epoch PCC data into
    pccEpoch = []
    
    # Iterate through each band
    for i in range(epoch.shape[0]):
        # Get the band of the index
        band = epoch[i]
        # Extract PCC from the band
        pcc = np.corrcoef(band)
        # Append PCC features into pccEpoch list
        pccEpoch.append(pcc)

    # Take the list of 2D numpy arrays and
    # convert it to 3D matrix
    pccEpoch = np.stack(pccEpoch)
    # Append the pccEpoch to pccData list
    pccData.append(pccEpoch)
    
# Take the list of 3D numpy arrays and
# convert it to 4D matrix
pccData = np.stack(pccData)

print("pccData Shape:", pccData.shape)
# Out:
# epochData Shape: (4275, 4, 14, 1600)
# pccData Shape: (4275, 4, 14, 14)

# %% [markdown]
# # Resphape to Multi-Image Format
#
# - 4 x 14 x 14 ==> 14 x 14 x 2
# - This is the format that works for images with rgb values
#     - A 2D matrix with 3 rgb values (n x m x 3)
#     - We have a 2D matrix with 4 bands of data
#
# Input Matrix Shape: `4275 x 14 x 14 x 4`

# %%
# Initialize empty list to put reshaped data into
reshapedData = [np.transpose(i, (1, 2, 0)) for i in pccData]
reshapedData = np.stack(reshapedData)

print("reshapedData Shape:", reshapedData.shape)
# Out:
# reshapedData Shape: (4275, 14, 14, 4)

# %% [markdown]
# ## Split Training and Testing Set
#
# - 80% Training, 20% Testing
#
# Training Input Matrix Shape: `3420 x 14 x 14 x 4`
#
# Training Output Matrix Shape: `3420 x 3`
#
# Testing Input Matrix Shape: `855 x 14 x 14 x 4`
#
# Testing Output Matrix Shape: `855 x 3`

# %%
print("Input Shape:", reshapedData.shape)
print("Output Shape:", epochLabels.shape)

x_train, x_test, y_train, y_test = train_test_split(reshapedData, epochLabels, random_state=0, train_size = 0.8)

print()
print("x_train Shape:", x_train.shape)
print("y_train Shape:", y_train.shape)
print("x_test Shape:", x_test.shape)
print("y_test Shape:", y_test.shape)
# Out:
# Input Shape: (4275, 14, 14, 4)
# Output Shape: (4275, 3)
#
# x_train Shape: (3420, 14, 14, 4)
# y_train Shape: (3420, 3)
# x_test Shape: (855, 14, 14, 4)
# y_test Shape: (855, 3)

# %% [markdown]
# ## Develop Convolutional Neural Network (CNN)
#
# - Input Convolutional Layer
#     - Input Size: Four 14 x 14 "images" (4 bands PCC matrix)
#     - Kernel Size = 3 x 1
#     - \# of Kernels = 32
# - Hidden Convolutional Layer
#     - Kernel Size = 3 x 1
#     - \# of Kernels = 64
# - Dropout Layer
# - Hidden Max-Pooling Layer
#     - Pooling Size = 3 x 3
# - Dropout Layer
# - Staging Layer
#     - Shape: 3 x 4 x 64
# - Output Layer
#     - (Valence, Arousal) tuple

# %%
CNN_1 = models.Sequential()
CNN_1.add(layers.Conv2D(32, (3, 1), activation='relu', input_shape=(14,14,4)))
CNN_1.add(layers.Dropout(0.2))
CNN_1.add(layers.Conv2D(64, (3, 1), activation='relu'))
CNN_1.add(layers.Dropout(0.2))
CNN_1.add(layers.MaxPooling2D(pool_size=(3,3)))
CNN_1.add(layers.Flatten())
CNN_1.add(layers.Dense(512, activation='relu', name="CNN_Output"))
CNN_1.add(layers.Dense(3, activation='softmax'))

CNN_1.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 12, 14, 32)        416
#
#  dropout (Dropout)           (None, 12, 14, 32)        0
#
#  conv2d_1 (Conv2D)           (None, 10, 14, 64)        6208
#
#  dropout_1 (Dropout)         (None, 10, 14, 64)        0
#
#  max_pooling2d (MaxPooling2D  (None, 3, 4, 64)         0
#  )
#
#  flatten (Flatten)           (None, 768)               0
#
#  CNN_Output (Dense)          (None, 512)               393728
#
#  dense (Dense)               (None, 3)                 1539
#
# =================================================================
# Total params: 401,891
# Trainable params: 401,891
# Non-trainable params: 0
# _________________________________________________________________
# 2023-03-27 20:48:09.202084: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [markdown]
# ## Train CNN
#
# - Training Epochs = 50
# - Batch Size = 128
# - Learning Rate = 0.01
# - Optimizer = "adam"

# %%
# Will be implemented once we know what the output data is.
CNN_1.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

history = CNN_1.fit(x_train, y_train, epochs=50, batch_size=128,
                    validation_data=(x_test, y_test))
# Out:
# Epoch 1/50
# 27/27 [==============================] - 2s 38ms/step - loss: 1.1246 - accuracy: 0.3751 - val_loss: 1.0540 - val_accuracy: 0.4608
# Epoch 2/50
# 27/27 [==============================] - 1s 31ms/step - loss: 1.0311 - accuracy: 0.4538 - val_loss: 1.0127 - val_accuracy: 0.4690
# Epoch 3/50
# 27/27 [==============================] - 1s 32ms/step - loss: 0.9731 - accuracy: 0.5126 - val_loss: 0.9843 - val_accuracy: 0.4865
# Epoch 4/50
# 27/27 [==============================] - 1s 30ms/step - loss: 0.9377 - accuracy: 0.5231 - val_loss: 0.9297 - val_accuracy: 0.5287
# Epoch 5/50
# 27/27 [==============================] - 1s 30ms/step - loss: 0.9004 - accuracy: 0.5705 - val_loss: 0.9178 - val_accuracy: 0.5322
# Epoch 6/50
# 27/27 [==============================] - 1s 31ms/step - loss: 0.8724 - accuracy: 0.5842 - val_loss: 0.8866 - val_accuracy: 0.5719
# Epoch 7/50
# 27/27 [==============================] - 1s 31ms/step - loss: 0.8622 - accuracy: 0.5871 - val_loss: 0.8569 - val_accuracy: 0.5813
# Epoch 8/50
# 27/27 [==============================] - 1s 31ms/step - loss: 0.8341 - accuracy: 0.6073 - val_loss: 0.8220 - val_accuracy: 0.6281
# Epoch 9/50
# 27/27 [==============================] - 1s 31ms/step - loss: 0.8120 - accuracy: 0.6301 - val_loss: 0.8060 - val_accuracy: 0.6480
# Epoch 10/50
# 27/27 [==============================] - 1s 30ms/step - loss: 0.7956 - accuracy: 0.6351 - val_loss: 0.7870 - val_accuracy: 0.6456
# Epoch 11/50
# 27/27 [==============================] - 1s 31ms/step - loss: 0.7789 - accuracy: 0.6494 - val_loss: 0.7668 - val_accuracy: 0.6643
# Epoch 12/50
# 27/27 [==============================] - 1s 30ms/step - loss: 0.7593 - accuracy: 0.6547 - val_loss: 0.7485 - val_accuracy: 0.6608
# Epoch 13/50
# 27/27 [==============================] - 1s 31ms/step - loss: 0.7396 - accuracy: 0.6673 - val_loss: 0.7365 - val_accuracy: 0.6690
# Epoch 14/50
# 27/27 [==============================] - 1s 32ms/step - loss: 0.7348 - accuracy: 0.6664 - val_loss: 0.7422 - val_accuracy: 0.6632
# Epoch 15/50
# 27/27 [==============================] - 1s 30ms/step - loss: 0.7220 - accuracy: 0.6784 - val_loss: 0.7094 - val_accuracy: 0.6889
# Epoch 16/50
# 27/27 [==============================] - 1s 30ms/step - loss: 0.7064 - accuracy: 0.6833 - val_loss: 0.7298 - val_accuracy: 0.6608
# Epoch 17/50
# 27/27 [==============================] - 1s 31ms/step - loss: 0.6760 - accuracy: 0.6971 - val_loss: 0.6841 - val_accuracy: 0.6912
# Epoch 18/50
# 27/27 [==============================] - 1s 30ms/step - loss: 0.6758 - accuracy: 0.7006 - val_loss: 0.6885 - val_accuracy: 0.6819
# Epoch 19/50
# 27/27 [==============================] - 1s 31ms/step - loss: 0.6754 - accuracy: 0.7050 - val_loss: 0.6790 - val_accuracy: 0.6924
# Epoch 20/50
# 27/27 [==============================] - 1s 31ms/step - loss: 0.6511 - accuracy: 0.7135 - val_loss: 0.6613 - val_accuracy: 0.7018
# Epoch 21/50
# 27/27 [==============================] - 1s 31ms/step - loss: 0.6533 - accuracy: 0.7079 - val_loss: 0.7082 - val_accuracy: 0.6713
# Epoch 22/50
# 27/27 [==============================] - 1s 30ms/step - loss: 0.6368 - accuracy: 0.7193 - val_loss: 0.6766 - val_accuracy: 0.6959
# Epoch 23/50
# 27/27 [==============================] - 1s 32ms/step - loss: 0.6502 - accuracy: 0.7099 - val_loss: 0.6906 - val_accuracy: 0.6749
# Epoch 24/50
# 27/27 [==============================] - 1s 31ms/step - loss: 0.6268 - accuracy: 0.7228 - val_loss: 0.6351 - val_accuracy: 0.7076
# Epoch 25/50
# 27/27 [==============================] - 1s 32ms/step - loss: 0.6227 - accuracy: 0.7272 - val_loss: 0.6669 - val_accuracy: 0.6842
# Epoch 26/50
# 27/27 [==============================] - 1s 30ms/step - loss: 0.5979 - accuracy: 0.7392 - val_loss: 0.6254 - val_accuracy: 0.7111
# Epoch 27/50
# 27/27 [==============================] - 1s 31ms/step - loss: 0.6137 - accuracy: 0.7374 - val_loss: 0.6149 - val_accuracy: 0.7298
# Epoch 28/50
# 27/27 [==============================] - 1s 30ms/step - loss: 0.5983 - accuracy: 0.7351 - val_loss: 0.6001 - val_accuracy: 0.7333
# Epoch 29/50
# 27/27 [==============================] - 1s 30ms/step - loss: 0.5720 - accuracy: 0.7561 - val_loss: 0.5995 - val_accuracy: 0.7263
# Epoch 30/50
# 27/27 [==============================] - 1s 31ms/step - loss: 0.5496 - accuracy: 0.7649 - val_loss: 0.6050 - val_accuracy: 0.7263
# Epoch 31/50
# 27/27 [==============================] - 1s 30ms/step - loss: 0.5708 - accuracy: 0.7462 - val_loss: 0.6199 - val_accuracy: 0.7322
# Epoch 32/50
# 27/27 [==============================] - 1s 31ms/step - loss: 0.5518 - accuracy: 0.7763 - val_loss: 0.5737 - val_accuracy: 0.7310
# Epoch 33/50
# 27/27 [==============================] - 1s 32ms/step - loss: 0.5488 - accuracy: 0.7640 - val_loss: 0.5807 - val_accuracy: 0.7380
# Epoch 34/50
# 27/27 [==============================] - 1s 30ms/step - loss: 0.5466 - accuracy: 0.7585 - val_loss: 0.5587 - val_accuracy: 0.7567
# Epoch 35/50
# 27/27 [==============================] - 1s 30ms/step - loss: 0.5230 - accuracy: 0.7865 - val_loss: 0.5646 - val_accuracy: 0.7439
# Epoch 36/50
# 27/27 [==============================] - 1s 30ms/step - loss: 0.5353 - accuracy: 0.7754 - val_loss: 0.5791 - val_accuracy: 0.7462
# Epoch 37/50
# 27/27 [==============================] - 1s 30ms/step - loss: 0.5134 - accuracy: 0.7865 - val_loss: 0.5891 - val_accuracy: 0.7216
# Epoch 38/50
# 27/27 [==============================] - 1s 29ms/step - loss: 0.5071 - accuracy: 0.7842 - val_loss: 0.5440 - val_accuracy: 0.7696
# Epoch 39/50
# 27/27 [==============================] - 1s 31ms/step - loss: 0.4973 - accuracy: 0.7895 - val_loss: 0.5612 - val_accuracy: 0.7415
# Epoch 40/50
# 27/27 [==============================] - 1s 31ms/step - loss: 0.4788 - accuracy: 0.8020 - val_loss: 0.5304 - val_accuracy: 0.7673
# Epoch 41/50
# 27/27 [==============================] - 1s 31ms/step - loss: 0.4717 - accuracy: 0.8085 - val_loss: 0.5339 - val_accuracy: 0.7614
# Epoch 42/50
# 27/27 [==============================] - 1s 32ms/step - loss: 0.4657 - accuracy: 0.8047 - val_loss: 0.5447 - val_accuracy: 0.7579
# Epoch 43/50
# 27/27 [==============================] - 1s 31ms/step - loss: 0.4546 - accuracy: 0.8053 - val_loss: 0.5468 - val_accuracy: 0.7509
# Epoch 44/50
# 27/27 [==============================] - 1s 30ms/step - loss: 0.4591 - accuracy: 0.8015 - val_loss: 0.5286 - val_accuracy: 0.7708
# Epoch 45/50
# 27/27 [==============================] - 1s 30ms/step - loss: 0.4379 - accuracy: 0.8190 - val_loss: 0.5313 - val_accuracy: 0.7649
# Epoch 46/50
# 27/27 [==============================] - 1s 30ms/step - loss: 0.4458 - accuracy: 0.8135 - val_loss: 0.5024 - val_accuracy: 0.7754
# Epoch 47/50
# 27/27 [==============================] - 1s 30ms/step - loss: 0.4416 - accuracy: 0.8216 - val_loss: 0.5330 - val_accuracy: 0.7696
# Epoch 48/50
# 27/27 [==============================] - 1s 31ms/step - loss: 0.4185 - accuracy: 0.8313 - val_loss: 0.4987 - val_accuracy: 0.7930
# Epoch 49/50
# 27/27 [==============================] - 1s 30ms/step - loss: 0.4250 - accuracy: 0.8193 - val_loss: 0.4860 - val_accuracy: 0.7731
# Epoch 50/50
# 27/27 [==============================] - 1s 32ms/step - loss: 0.4241 - accuracy: 0.8193 - val_loss: 0.4719 - val_accuracy: 0.8012

# %%
plt.plot(history.history['accuracy'], label='accuracy')
plt.plot(history.history['val_accuracy'], label='val_accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.ylim([0.5, 1])
plt.legend(loc='lower right')

test_loss, test_acc = CNN_1.evaluate(x_test, y_test, verbose=2)

print("test_acc:", test_acc)
# Out:
# 27/27 - 0s - loss: 0.4719 - accuracy: 0.8012 - 99ms/epoch - 4ms/step
# test_acc: 0.8011695742607117

# %% [markdown]
# ## After Training, Drop Output Layer
#
# - This makes the Staging Layer the new Output Layer
# - Run Training Input Matrix through CNN an get the output.
# - **Note:** Just using a CNN for classification is known to not have the best results. This is the main idea of the paper. We initially have a 2-neuron output layer for training in order for back propagation in the CNN to adjust the weights, but then dorp the output layer and take the data in the staging layer, flatten it, and put it into the SAE

# %%
# Initialize Test Input
test_in = np.expand_dims(x_train[0], axis=0)
print(test_in.shape)

# Test Output Before
out = CNN_1.predict(test_in)
print("Original Output Shape:", out.shape)
print("Original Output:", out)

# Drop Fully Connected Output Layer
CNN_1.summary()
CNN_2 = models.Model(inputs=CNN_1.input, outputs=CNN_1.get_layer("CNN_Output").output)
CNN_2.summary()

# Test Output After
out = CNN_2.predict(test_in)
print("Dropped Output Shape:", out.shape)
# Out:
# (1, 14, 14, 4)
# 1/1 [==============================] - 0s 95ms/step
# Original Output Shape: (1, 3)
# Original Output: [[0.02148008 0.91751164 0.06100825]]
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 12, 14, 32)        416
#
#  dropout (Dropout)           (None, 12, 14, 32)        0
#
#  conv2d_1 (Conv2D)           (None, 10, 14, 64)        6208
#
#  dropout_1 (Dropout)         (None, 10, 14, 64)        0
#
#  max_pooling2d (MaxPooling2D  (None, 3, 4, 64)         0
#  )
#
#  flatten (Flatten)           (None, 768)               0
#
#  CNN_Output (Dense)          (None, 512)               393728
#
#  dense (Dense)               (None, 3)                 1539
#
# =================================================================
# Total params: 401,891
# Trainable params: 401,891
# Non-trainable params: 0
# _________________________________________________________________
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_input (InputLayer)   [(None, 14, 14, 4)]       0
#
#  conv2d (Conv2D)             (None, 12, 14, 32)        416
#
#  dropout (Dropout)           (None, 12, 14, 32)        0
#
#  conv2d_1 (Conv2D)           (None, 10, 14, 64)        6208
#
#  dropout_1 (Dropout)         (None, 10, 14, 64)        0
#
#  max_pooling2d (MaxPooling2D  (None, 3, 4, 64)         0
#  )
#
#  flatten (Flatten)           (None, 768)               0
#
#  CNN_Output (Dense)          (None, 512)               393728
#
# =================================================================
# Total params: 400,352
# Trainable params: 400,352
# Non-trainable params: 0
# _________________________________________________________________
# 1/1 [==============================] - 0s 54ms/step
# Dropped Output Shape: (1, 512)

# %% [markdown]
# ## Get Training Data for SAE
#
# - Data needs to be one-dimensional to go into SAE
#
# Training Input Matrix Size: `14336 x 5760`

# %%
# Print Shape of Input going into CNN model
print("Train Input to CNN Shape:", x_train.shape)
print("Test Input to CNN Shape:", x_test.shape)

# Get the output of the trained CNN for training and testing input in the SAE
train_SAE = CNN_2.predict(x_train)
test_SAE = CNN_2.predict(x_test)

# Print Shape of Output from CNN
print("SAE Training Input Shape:", train_SAE.shape)
print("SAE Testing Input Shape:", test_SAE.shape)
# Out:
# Train Input to CNN Shape: (3420, 14, 14, 4)
# Test Input to CNN Shape: (855, 14, 14, 4)
# 107/107 [==============================] - 0s 2ms/step
# 27/27 [==============================] - 0s 3ms/step
# SAE Training Input Shape: (3420, 512)
# SAE Testing Input Shape: (855, 512)

# %% [markdown]
# ## Develop Sparse Autoencoder (SAE)
#
# - Input Layer: 6080 Nodes
# - Encoder Layer: 512 Nodes
# - Hidden Layer: 128 Nodes
# - Output Decoder Layer: 512 Nodes

# %%
# Shapes
SAE_n_inputs = train_SAE.shape[1]
SAE_n_hidden = 128

# Layers
SAE_visible = layers.Input(shape=(SAE_n_inputs,), name='SAE-Input-Layer')
SAE_enc_hidden = layers.Dense(units=SAE_n_inputs, activation='relu', name='SAE-Encoder-Hidden-Layer')(SAE_visible)
SAE_bottleneck = layers.Dense(units=SAE_n_hidden, activation='relu', activity_regularizer=keras.regularizers.L1(0.0001), name='SAE-Bottleneck-Layer')(SAE_enc_hidden)
SAE_dec_output = layers.Dense(units=SAE_n_inputs, activation='relu', name='SAE-Decoder-Output-Layer')(SAE_bottleneck)

# Define Sparse Autoencoder Model
SAE_model = models.Model(inputs=SAE_visible, outputs=SAE_dec_output, name='Sparse-Autoencoder-Model')

# Print Model Summary
print(SAE_model.summary())
# Out:
# Model: "Sparse-Autoencoder-Model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  SAE-Input-Layer (InputLayer  [(None, 512)]            0
#  )
#
#  SAE-Encoder-Hidden-Layer (D  (None, 512)              262656
#  ense)
#
#  SAE-Bottleneck-Layer (Dense  (None, 128)              65664
#  )
#
#  SAE-Decoder-Output-Layer (D  (None, 512)              66048
#  ense)
#
# =================================================================
# Total params: 394,368
# Trainable params: 394,368
# Non-trainable params: 0
# _________________________________________________________________
# None

# %% [markdown]
# ## Train SAE
#
# - SAE's are unsupervised learning models so we don't train it against an expected output.
# - Training Epochs = 100
# - Batch Size = 64
# - Learning Rate = 0.01

# %%
# Compile Sparse Autoencoder Model
SAE_model.compile(optimizer='adam', loss='mse')

# Fit the Sparse Autoencoder Model to Reconstruct Input
SAE_history = SAE_model.fit(train_SAE, train_SAE, epochs=100, batch_size=64, verbose=1, validation_data=(test_SAE, test_SAE))
# Out:
# Epoch 1/100
# 54/54 [==============================] - 1s 8ms/step - loss: 0.0183 - val_loss: 0.0088
# Epoch 2/100
# 54/54 [==============================] - 0s 6ms/step - loss: 0.0070 - val_loss: 0.0057
# Epoch 3/100
# 54/54 [==============================] - 0s 6ms/step - loss: 0.0051 - val_loss: 0.0044
# Epoch 4/100
# 54/54 [==============================] - 0s 6ms/step - loss: 0.0041 - val_loss: 0.0039
# Epoch 5/100
# 54/54 [==============================] - 0s 5ms/step - loss: 0.0037 - val_loss: 0.0035
# Epoch 6/100
# 54/54 [==============================] - 0s 6ms/step - loss: 0.0034 - val_loss: 0.0032
# Epoch 7/100
# 54/54 [==============================] - 0s 5ms/step - loss: 0.0032 - val_loss: 0.0030
# Epoch 8/100
# 54/54 [==============================] - 0s 5ms/step - loss: 0.0030 - val_loss: 0.0028
# Epoch 9/100
# 54/54 [==============================] - 0s 5ms/step - loss: 0.0028 - val_loss: 0.0027
# Epoch 10/100
# 54/54 [==============================] - 0s 6ms/step - loss: 0.0026 - val_loss: 0.0025
# Epoch 11/100
# 54/54 [==============================] - 0s 5ms/step - loss: 0.0024 - val_loss: 0.0024
# Epoch 12/100
# 54/54 [==============================] - 0s 6ms/step - loss: 0.0023 - val_loss: 0.0023
# Epoch 13/100
# 54/54 [==============================] - 0s 6ms/step - loss: 0.0023 - val_loss: 0.0023
# Epoch 14/100
# 54/54 [==============================] - 0s 6ms/step - loss: 0.0022 - val_loss: 0.0022
# Epoch 15/100
# 54/54 [==============================] - 0s 5ms/step - loss: 0.0022 - val_loss: 0.0022
# Epoch 16/100
# 54/54 [==============================] - 0s 6ms/step - loss: 0.0021 - val_loss: 0.0021
# Epoch 17/100
# 54/54 [==============================] - 0s 6ms/step - loss: 0.0020 - val_loss: 0.0021
# Epoch 18/100
# 54/54 [==============================] - 0s 5ms/step - loss: 0.0020 - val_loss: 0.0021
# Epoch 19/100
# 54/54 [==============================] - 0s 6ms/step - loss: 0.0020 - val_loss: 0.0020
# Epoch 20/100
# 54/54 [==============================] - 0s 5ms/step - loss: 0.0020 - val_loss: 0.0020
# Epoch 21/100
# 54/54 [==============================] - 0s 6ms/step - loss: 0.0019 - val_loss: 0.0020
# Epoch 22/100
# 54/54 [==============================] - 0s 5ms/step - loss: 0.0019 - val_loss: 0.0019
# Epoch 23/100
# 54/54 [==============================] - 0s 5ms/step - loss: 0.0018 - val_loss: 0.0019
# Epoch 24/100
# 54/54 [==============================] - 0s 5ms/step - loss: 0.0018 - val_loss: 0.0018
# Epoch 25/100
# 54/54 [==============================] - 0s 6ms/step - loss: 0.0018 - val_loss: 0.0018
# Epoch 26/100
# 54/54 [==============================] - 0s 5ms/step - loss: 0.0017 - val_loss: 0.0018
# Epoch 27/100
# 54/54 [==============================] - 0s 5ms/step - loss: 0.0017 - val_loss: 0.0018
# Epoch 28/100
# 54/54 [==============================] - 0s 5ms/step - loss: 0.0017 - val_loss: 0.0018
# Epoch 29/100
# 54/54 [==============================] - 0s 6ms/step - loss: 0.0017 - val_loss: 0.0017
# Epoch 30/100
# 54/54 [==============================] - 0s 5ms/step - loss: 0.0016 - val_loss: 0.0017
# Epoch 31/100
# 54/54 [==============================] - 0s 5ms/step - loss: 0.0016 - val_loss: 0.0017
# Epoch 32/100
# 54/54 [==============================] - 0s 5ms/step - loss: 0.0016 - val_loss: 0.0017
# Epoch 33/100
# 54/54 [==============================] - 0s 5ms/step - loss: 0.0016 - val_loss: 0.0017
# Epoch 34/100
# 54/54 [==============================] - 0s 5ms/step - loss: 0.0016 - val_loss: 0.0017
# Epoch 35/100
# 54/54 [==============================] - 0s 5ms/step - loss: 0.0016 - val_loss: 0.0017
# Epoch 36/100
# 54/54 [==============================] - 0s 5ms/step - loss: 0.0016 - val_loss: 0.0016
# Epoch 37/100
# 54/54 [==============================] - 0s 5ms/step - loss: 0.0015 - val_loss: 0.0016
# Epoch 38/100
# 54/54 [==============================] - 0s 5ms/step - loss: 0.0015 - val_loss: 0.0016
# Epoch 39/100
# 54/54 [==============================] - 0s 5ms/step - loss: 0.0015 - val_loss: 0.0016
# Epoch 40/100
# 54/54 [==============================] - 0s 5ms/step - loss: 0.0015 - val_loss: 0.0016
# Epoch 41/100
# 54/54 [==============================] - 0s 5ms/step - loss: 0.0015 - val_loss: 0.0016
# Epoch 42/100
# 54/54 [==============================] - 0s 5ms/step - loss: 0.0015 - val_loss: 0.0016
# Epoch 43/100
# 54/54 [==============================] - 0s 5ms/step - loss: 0.0015 - val_loss: 0.0016
# Epoch 44/100
# 54/54 [==============================] - 0s 5ms/step - loss: 0.0015 - val_loss: 0.0016
# Epoch 45/100
# 54/54 [==============================] - 0s 6ms/step - loss: 0.0015 - val_loss: 0.0016
# Epoch 46/100
# 54/54 [==============================] - 0s 6ms/step - loss: 0.0015 - val_loss: 0.0015
# Epoch 47/100
# 54/54 [==============================] - 0s 5ms/step - loss: 0.0014 - val_loss: 0.0015
# Epoch 48/100
# 54/54 [==============================] - 0s 6ms/step - loss: 0.0014 - val_loss: 0.0015
# Epoch 49/100
# 54/54 [==============================] - 0s 5ms/step - loss: 0.0014 - val_loss: 0.0015
# Epoch 50/100
# 54/54 [==============================] - 0s 6ms/step - loss: 0.0014 - val_loss: 0.0015
# Epoch 51/100
# 54/54 [==============================] - 0s 5ms/step - loss: 0.0013 - val_loss: 0.0015
# Epoch 52/100
# 54/54 [==============================] - 0s 6ms/step - loss: 0.0013 - val_loss: 0.0015
# Epoch 53/100
# 54/54 [==============================] - 0s 5ms/step - loss: 0.0013 - val_loss: 0.0014
# Epoch 54/100
# 54/54 [==============================] - 0s 7ms/step - loss: 0.0013 - val_loss: 0.0014
# Epoch 55/100
# 54/54 [==============================] - 0s 6ms/step - loss: 0.0013 - val_loss: 0.0014
# Epoch 56/100
# 54/54 [==============================] - 0s 5ms/step - loss: 0.0013 - val_loss: 0.0014
# Epoch 57/100
# 54/54 [==============================] - 0s 5ms/step - loss: 0.0013 - val_loss: 0.0015
# Epoch 58/100
# 54/54 [==============================] - 0s 5ms/step - loss: 0.0013 - val_loss: 0.0014
# Epoch 59/100
# 54/54 [==============================] - 0s 5ms/step - loss: 0.0013 - val_loss: 0.0014
# Epoch 60/100
# 54/54 [==============================] - 0s 5ms/step - loss: 0.0013 - val_loss: 0.0014
# Epoch 61/100
# 54/54 [==============================] - 0s 6ms/step - loss: 0.0013 - val_loss: 0.0014
# Epoch 62/100
# 54/54 [==============================] - 0s 5ms/step - loss: 0.0013 - val_loss: 0.0014
# Epoch 63/100
# 54/54 [==============================] - 0s 5ms/step - loss: 0.0012 - val_loss: 0.0014
# Epoch 64/100
# 54/54 [==============================] - 0s 5ms/step - loss: 0.0013 - val_loss: 0.0014
# Epoch 65/100
# 54/54 [==============================] - 0s 6ms/step - loss: 0.0012 - val_loss: 0.0014
# Epoch 66/100
# 54/54 [==============================] - 0s 5ms/step - loss: 0.0012 - val_loss: 0.0014
# Epoch 67/100
# 54/54 [==============================] - 0s 5ms/step - loss: 0.0012 - val_loss: 0.0014
# Epoch 68/100
# 54/54 [==============================] - 0s 5ms/step - loss: 0.0012 - val_loss: 0.0014
# Epoch 69/100
# 54/54 [==============================] - 0s 5ms/step - loss: 0.0012 - val_loss: 0.0014
# Epoch 70/100
# 54/54 [==============================] - 0s 6ms/step - loss: 0.0012 - val_loss: 0.0013
# Epoch 71/100
# 54/54 [==============================] - 0s 5ms/step - loss: 0.0012 - val_loss: 0.0014
# Epoch 72/100
# 54/54 [==============================] - 0s 6ms/step - loss: 0.0012 - val_loss: 0.0013
# Epoch 73/100
# 54/54 [==============================] - 0s 6ms/step - loss: 0.0012 - val_loss: 0.0013
# Epoch 74/100
# 54/54 [==============================] - 0s 6ms/step - loss: 0.0012 - val_loss: 0.0013
# Epoch 75/100
# 54/54 [==============================] - 0s 5ms/step - loss: 0.0012 - val_loss: 0.0013
# Epoch 76/100
# 54/54 [==============================] - 0s 5ms/step - loss: 0.0012 - val_loss: 0.0013
# Epoch 77/100
# 54/54 [==============================] - 0s 6ms/step - loss: 0.0012 - val_loss: 0.0014
# Epoch 78/100
# 54/54 [==============================] - 0s 6ms/step - loss: 0.0012 - val_loss: 0.0015
# Epoch 79/100
# 54/54 [==============================] - 0s 5ms/step - loss: 0.0013 - val_loss: 0.0013
# Epoch 80/100
# 54/54 [==============================] - 0s 5ms/step - loss: 0.0012 - val_loss: 0.0013
# Epoch 81/100
# 54/54 [==============================] - 0s 6ms/step - loss: 0.0012 - val_loss: 0.0013
# Epoch 82/100
# 54/54 [==============================] - 0s 5ms/step - loss: 0.0011 - val_loss: 0.0013
# Epoch 83/100
# 54/54 [==============================] - 0s 5ms/step - loss: 0.0011 - val_loss: 0.0013
# Epoch 84/100
# 54/54 [==============================] - 0s 6ms/step - loss: 0.0011 - val_loss: 0.0013
# Epoch 85/100
# 54/54 [==============================] - 0s 5ms/step - loss: 0.0011 - val_loss: 0.0013
# Epoch 86/100
# 54/54 [==============================] - 0s 5ms/step - loss: 0.0011 - val_loss: 0.0013
# Epoch 87/100
# 54/54 [==============================] - 0s 5ms/step - loss: 0.0011 - val_loss: 0.0013
# Epoch 88/100
# 54/54 [==============================] - 0s 5ms/step - loss: 0.0011 - val_loss: 0.0013
# Epoch 89/100
# 54/54 [==============================] - 0s 6ms/step - loss: 0.0011 - val_loss: 0.0013
# Epoch 90/100
# 54/54 [==============================] - 0s 6ms/step - loss: 0.0011 - val_loss: 0.0013
# Epoch 91/100
# 54/54 [==============================] - 0s 5ms/step - loss: 0.0011 - val_loss: 0.0013
# Epoch 92/100
# 54/54 [==============================] - 0s 5ms/step - loss: 0.0011 - val_loss: 0.0013
# Epoch 93/100
# 54/54 [==============================] - 0s 5ms/step - loss: 0.0011 - val_loss: 0.0013
# Epoch 94/100
# 54/54 [==============================] - 0s 5ms/step - loss: 0.0011 - val_loss: 0.0013
# Epoch 95/100
# 54/54 [==============================] - 0s 5ms/step - loss: 0.0011 - val_loss: 0.0013
# Epoch 96/100
# 54/54 [==============================] - 0s 6ms/step - loss: 0.0011 - val_loss: 0.0012
# Epoch 97/100
# 54/54 [==============================] - 0s 6ms/step - loss: 0.0011 - val_loss: 0.0013
# Epoch 98/100
# 54/54 [==============================] - 0s 6ms/step - loss: 0.0011 - val_loss: 0.0012
# Epoch 99/100
# 54/54 [==============================] - 0s 5ms/step - loss: 0.0011 - val_loss: 0.0012
# Epoch 100/100
# 54/54 [==============================] - 0s 6ms/step - loss: 0.0011 - val_loss: 0.0012

# %%
#---------- Plot a loss chart ----------#
fig, ax = plt.subplots(figsize=(16,9), dpi=300)
plt.title(label='SAE Model Loss by Epoch', loc='center')
ax.plot(SAE_history.history['loss'], label='Training Data', color='black')
ax.plot(SAE_history.history['val_loss'], label='Test Data', color='red')
ax.set(xlabel='Epoch', ylabel='Loss')
plt.legend()
plt.show()

# %% [markdown]
# ## Get SAE Output
#
# - Using the flattened output from the CNN as input to the trained SAE, get the output to use as training data for DNN
#
# Training Input Matrix Shape: `4275 x 512`

# %%
cnn_out = CNN_2.predict(reshapedData)
sae_out = SAE_model.predict(cnn_out)
print("DNN Training Input Shape:", sae_out.shape)
# Out:
# 134/134 [==============================] - 0s 2ms/step
# 134/134 [==============================] - 0s 1ms/step
# DNN Training Input Shape: (4275, 512)

# %% [markdown]
# # Split Train and Test Set from SAE Output

# %%
print("Input Shape:", sae_out.shape)
print("Output Shape:", epochLabels.shape)

x_train, x_test, y_train, y_test = train_test_split(sae_out, epochLabels, random_state=0, train_size = 0.8)

print()
print("x_train Shape:", x_train.shape)
print("y_train Shape:", y_train.shape)
print("x_test Shape:", x_test.shape)
print("y_test Shape:", y_test.shape)
# Out:
# Input Shape: (4275, 512)
# Output Shape: (4275, 3)
#
# x_train Shape: (3420, 512)
# y_train Shape: (3420, 3)
# x_test Shape: (855, 512)
# y_test Shape: (855, 3)

# %% [markdown]
# ## Develop Deep Neural Network (DNN)
#
# - Fully Connected Input Layer: 512 Nodes
# - Fully Connected Hidden Layer: 256 Nodes
# - Fully Connected Output Layer: 3 Nodes ((Negative, Neutral, Positive) tuple)

# %%
# Shapes
DNN_n_inputs  = x_train.shape[1]
DNN_n_hidden  = 256
DNN_n_outputs = 3
print(DNN_n_inputs)
# Layers
DNN_input = layers.Input(shape=(DNN_n_inputs,), name='DNN-Input-Layer')
DNN_hidden = layers.Dense(DNN_n_hidden, activation='relu', name='DNN-Hidden-Layer')(DNN_input)
DNN_output = layers.Dense(DNN_n_outputs, activation='sigmoid', name='DNN-Output-Layer')(DNN_hidden)

# Define DNN Model
DNN_model = models.Model(inputs=DNN_input, outputs=DNN_output, name='DNN-Model')

# Print Model Summary
print(DNN_model.summary())
# Out:
# 512
# Model: "DNN-Model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  DNN-Input-Layer (InputLayer  [(None, 512)]            0
#  )
#
#  DNN-Hidden-Layer (Dense)    (None, 256)               131328
#
#  DNN-Output-Layer (Dense)    (None, 3)                 771
#
# =================================================================
# Total params: 132,099
# Trainable params: 132,099
# Non-trainable params: 0
# _________________________________________________________________
# None

# %% [markdown]
# ## Train DNN
#
# - Use the output of the trained SAE as training input for the DNN. The expected outputs to the DNN are teh original (V,A) tuple.
# - Training Epochs = 100
# - Batch Size = 128
# - Learning Rate = 0.01

# %%
# Compile DNN Model
DNN_model.compile(optimizer='adam',
                  loss='categorical_crossentropy',
                  metrics=['accuracy'])

# Fit the DNN Model
DNN_history = DNN_model.fit(x_train, y_train, epochs=100, batch_size=128,
                            validation_data=(x_test, y_test))
# Out:
# Epoch 1/100
# 27/27 [==============================] - 1s 8ms/step - loss: 0.5758 - accuracy: 0.8167 - val_loss: 0.5047 - val_accuracy: 0.7766
# Epoch 2/100
# 27/27 [==============================] - 0s 3ms/step - loss: 0.2849 - accuracy: 0.8927 - val_loss: 0.4967 - val_accuracy: 0.7930
# Epoch 3/100
# 27/27 [==============================] - 0s 3ms/step - loss: 0.2443 - accuracy: 0.9038 - val_loss: 0.4953 - val_accuracy: 0.7977
# Epoch 4/100
# 27/27 [==============================] - 0s 3ms/step - loss: 0.2320 - accuracy: 0.9085 - val_loss: 0.5001 - val_accuracy: 0.8023
# Epoch 5/100
# 27/27 [==============================] - 0s 3ms/step - loss: 0.2184 - accuracy: 0.9102 - val_loss: 0.4930 - val_accuracy: 0.8140
# Epoch 6/100
# 27/27 [==============================] - 0s 3ms/step - loss: 0.2124 - accuracy: 0.9123 - val_loss: 0.4977 - val_accuracy: 0.8070
# Epoch 7/100
# 27/27 [==============================] - 0s 3ms/step - loss: 0.2056 - accuracy: 0.9211 - val_loss: 0.5004 - val_accuracy: 0.8140
# Epoch 8/100
# 27/27 [==============================] - 0s 4ms/step - loss: 0.2087 - accuracy: 0.9140 - val_loss: 0.4948 - val_accuracy: 0.8140
# Epoch 9/100
# 27/27 [==============================] - 0s 3ms/step - loss: 0.1993 - accuracy: 0.9199 - val_loss: 0.4893 - val_accuracy: 0.8281
# Epoch 10/100
# 27/27 [==============================] - 0s 3ms/step - loss: 0.1942 - accuracy: 0.9228 - val_loss: 0.4967 - val_accuracy: 0.8140
# Epoch 11/100
# 27/27 [==============================] - 0s 4ms/step - loss: 0.1926 - accuracy: 0.9257 - val_loss: 0.4938 - val_accuracy: 0.8211
# Epoch 12/100
# 27/27 [==============================] - 0s 3ms/step - loss: 0.1940 - accuracy: 0.9222 - val_loss: 0.5066 - val_accuracy: 0.8199
# Epoch 13/100
# 27/27 [==============================] - 0s 3ms/step - loss: 0.1904 - accuracy: 0.9254 - val_loss: 0.5012 - val_accuracy: 0.8257
# Epoch 14/100
# 27/27 [==============================] - 0s 4ms/step - loss: 0.1893 - accuracy: 0.9231 - val_loss: 0.4970 - val_accuracy: 0.8269
# Epoch 15/100
# 27/27 [==============================] - 0s 3ms/step - loss: 0.1820 - accuracy: 0.9307 - val_loss: 0.4931 - val_accuracy: 0.8234
# Epoch 16/100
# 27/27 [==============================] - 0s 3ms/step - loss: 0.1819 - accuracy: 0.9278 - val_loss: 0.4918 - val_accuracy: 0.8281
# Epoch 17/100
# 27/27 [==============================] - 0s 3ms/step - loss: 0.1808 - accuracy: 0.9284 - val_loss: 0.4983 - val_accuracy: 0.8234
# Epoch 18/100
# 27/27 [==============================] - 0s 3ms/step - loss: 0.1785 - accuracy: 0.9304 - val_loss: 0.4947 - val_accuracy: 0.8222
# Epoch 19/100
# 27/27 [==============================] - 0s 5ms/step - loss: 0.1783 - accuracy: 0.9287 - val_loss: 0.4988 - val_accuracy: 0.8269
# Epoch 20/100
# 27/27 [==============================] - 0s 3ms/step - loss: 0.1744 - accuracy: 0.9298 - val_loss: 0.5070 - val_accuracy: 0.8292
# Epoch 21/100
# 27/27 [==============================] - 0s 3ms/step - loss: 0.1713 - accuracy: 0.9345 - val_loss: 0.4888 - val_accuracy: 0.8327
# Epoch 22/100
# 27/27 [==============================] - 0s 4ms/step - loss: 0.1732 - accuracy: 0.9287 - val_loss: 0.4949 - val_accuracy: 0.8292
# Epoch 23/100
# 27/27 [==============================] - 0s 3ms/step - loss: 0.1655 - accuracy: 0.9360 - val_loss: 0.4950 - val_accuracy: 0.8327
# Epoch 24/100
# 27/27 [==============================] - 0s 4ms/step - loss: 0.1643 - accuracy: 0.9360 - val_loss: 0.4939 - val_accuracy: 0.8304
# Epoch 25/100
# 27/27 [==============================] - 0s 4ms/step - loss: 0.1677 - accuracy: 0.9333 - val_loss: 0.4945 - val_accuracy: 0.8281
# Epoch 26/100
# 27/27 [==============================] - 0s 3ms/step - loss: 0.1629 - accuracy: 0.9392 - val_loss: 0.5198 - val_accuracy: 0.8292
# Epoch 27/100
# 27/27 [==============================] - 0s 3ms/step - loss: 0.1639 - accuracy: 0.9374 - val_loss: 0.5066 - val_accuracy: 0.8292
# Epoch 28/100
# 27/27 [==============================] - 0s 3ms/step - loss: 0.1632 - accuracy: 0.9360 - val_loss: 0.5062 - val_accuracy: 0.8281
# Epoch 29/100
# 27/27 [==============================] - 0s 4ms/step - loss: 0.1618 - accuracy: 0.9365 - val_loss: 0.4960 - val_accuracy: 0.8363
# Epoch 30/100
# 27/27 [==============================] - 0s 4ms/step - loss: 0.1617 - accuracy: 0.9354 - val_loss: 0.5009 - val_accuracy: 0.8269
# Epoch 31/100
# 27/27 [==============================] - 0s 4ms/step - loss: 0.1629 - accuracy: 0.9363 - val_loss: 0.5093 - val_accuracy: 0.8292
# Epoch 32/100
# 27/27 [==============================] - 0s 5ms/step - loss: 0.1605 - accuracy: 0.9406 - val_loss: 0.4990 - val_accuracy: 0.8316
# Epoch 33/100
# 27/27 [==============================] - 0s 4ms/step - loss: 0.1585 - accuracy: 0.9398 - val_loss: 0.5054 - val_accuracy: 0.8339
# Epoch 34/100
# 27/27 [==============================] - 0s 3ms/step - loss: 0.1525 - accuracy: 0.9398 - val_loss: 0.5077 - val_accuracy: 0.8316
# Epoch 35/100
# 27/27 [==============================] - 0s 3ms/step - loss: 0.1510 - accuracy: 0.9406 - val_loss: 0.5046 - val_accuracy: 0.8386
# Epoch 36/100
# 27/27 [==============================] - 0s 4ms/step - loss: 0.1496 - accuracy: 0.9442 - val_loss: 0.4949 - val_accuracy: 0.8351
# Epoch 37/100
# 27/27 [==============================] - 0s 4ms/step - loss: 0.1483 - accuracy: 0.9415 - val_loss: 0.5042 - val_accuracy: 0.8374
# Epoch 38/100
# 27/27 [==============================] - 0s 4ms/step - loss: 0.1578 - accuracy: 0.9380 - val_loss: 0.5094 - val_accuracy: 0.8292
# Epoch 39/100
# 27/27 [==============================] - 0s 4ms/step - loss: 0.1549 - accuracy: 0.9383 - val_loss: 0.5165 - val_accuracy: 0.8327
# Epoch 40/100
# 27/27 [==============================] - 0s 3ms/step - loss: 0.1492 - accuracy: 0.9433 - val_loss: 0.5026 - val_accuracy: 0.8327
# Epoch 41/100
# 27/27 [==============================] - 0s 3ms/step - loss: 0.1428 - accuracy: 0.9453 - val_loss: 0.4993 - val_accuracy: 0.8339
# Epoch 42/100
# 27/27 [==============================] - 0s 3ms/step - loss: 0.1400 - accuracy: 0.9433 - val_loss: 0.5142 - val_accuracy: 0.8316
# Epoch 43/100
# 27/27 [==============================] - 0s 3ms/step - loss: 0.1425 - accuracy: 0.9436 - val_loss: 0.5126 - val_accuracy: 0.8351
# Epoch 44/100
# 27/27 [==============================] - 0s 4ms/step - loss: 0.1411 - accuracy: 0.9456 - val_loss: 0.5172 - val_accuracy: 0.8316
# Epoch 45/100
# 27/27 [==============================] - 0s 3ms/step - loss: 0.1401 - accuracy: 0.9468 - val_loss: 0.5249 - val_accuracy: 0.8292
# Epoch 46/100
# 27/27 [==============================] - 0s 3ms/step - loss: 0.1433 - accuracy: 0.9447 - val_loss: 0.5019 - val_accuracy: 0.8316
# Epoch 47/100
# 27/27 [==============================] - 0s 3ms/step - loss: 0.1431 - accuracy: 0.9450 - val_loss: 0.5148 - val_accuracy: 0.8304
# Epoch 48/100
# 27/27 [==============================] - 0s 3ms/step - loss: 0.1345 - accuracy: 0.9474 - val_loss: 0.5084 - val_accuracy: 0.8351
# Epoch 49/100
# 27/27 [==============================] - 0s 4ms/step - loss: 0.1360 - accuracy: 0.9456 - val_loss: 0.5055 - val_accuracy: 0.8327
# Epoch 50/100
# 27/27 [==============================] - 0s 3ms/step - loss: 0.1335 - accuracy: 0.9485 - val_loss: 0.5193 - val_accuracy: 0.8339
# Epoch 51/100
# 27/27 [==============================] - 0s 3ms/step - loss: 0.1350 - accuracy: 0.9468 - val_loss: 0.5140 - val_accuracy: 0.8292
# Epoch 52/100
# 27/27 [==============================] - 0s 3ms/step - loss: 0.1287 - accuracy: 0.9538 - val_loss: 0.5233 - val_accuracy: 0.8409
# Epoch 53/100
# 27/27 [==============================] - 0s 3ms/step - loss: 0.1307 - accuracy: 0.9520 - val_loss: 0.5089 - val_accuracy: 0.8386
# Epoch 54/100
# 27/27 [==============================] - 0s 3ms/step - loss: 0.1295 - accuracy: 0.9512 - val_loss: 0.5218 - val_accuracy: 0.8292
# Epoch 55/100
# 27/27 [==============================] - 0s 4ms/step - loss: 0.1287 - accuracy: 0.9506 - val_loss: 0.5170 - val_accuracy: 0.8351
# Epoch 56/100
# 27/27 [==============================] - 0s 3ms/step - loss: 0.1265 - accuracy: 0.9494 - val_loss: 0.5172 - val_accuracy: 0.8316
# Epoch 57/100
# 27/27 [==============================] - 0s 3ms/step - loss: 0.1302 - accuracy: 0.9485 - val_loss: 0.5163 - val_accuracy: 0.8409
# Epoch 58/100
# 27/27 [==============================] - 0s 3ms/step - loss: 0.1255 - accuracy: 0.9506 - val_loss: 0.5193 - val_accuracy: 0.8374
# Epoch 59/100
# 27/27 [==============================] - 0s 3ms/step - loss: 0.1274 - accuracy: 0.9506 - val_loss: 0.5263 - val_accuracy: 0.8292
# Epoch 60/100
# 27/27 [==============================] - 0s 3ms/step - loss: 0.1285 - accuracy: 0.9520 - val_loss: 0.5391 - val_accuracy: 0.8292
# Epoch 61/100
# 27/27 [==============================] - 0s 4ms/step - loss: 0.1210 - accuracy: 0.9523 - val_loss: 0.5382 - val_accuracy: 0.8351
# Epoch 62/100
# 27/27 [==============================] - 0s 4ms/step - loss: 0.1213 - accuracy: 0.9526 - val_loss: 0.5330 - val_accuracy: 0.8327
# Epoch 63/100
# 27/27 [==============================] - 0s 3ms/step - loss: 0.1234 - accuracy: 0.9506 - val_loss: 0.5273 - val_accuracy: 0.8351
# Epoch 64/100
# 27/27 [==============================] - 0s 3ms/step - loss: 0.1173 - accuracy: 0.9541 - val_loss: 0.5306 - val_accuracy: 0.8363
# Epoch 65/100
# 27/27 [==============================] - 0s 4ms/step - loss: 0.1165 - accuracy: 0.9550 - val_loss: 0.5618 - val_accuracy: 0.8281
# Epoch 66/100
# 27/27 [==============================] - 0s 3ms/step - loss: 0.1211 - accuracy: 0.9529 - val_loss: 0.5408 - val_accuracy: 0.8292
# Epoch 67/100
# 27/27 [==============================] - 0s 3ms/step - loss: 0.1205 - accuracy: 0.9520 - val_loss: 0.5591 - val_accuracy: 0.8246
# Epoch 68/100
# 27/27 [==============================] - 0s 3ms/step - loss: 0.1191 - accuracy: 0.9532 - val_loss: 0.5469 - val_accuracy: 0.8374
# Epoch 69/100
# 27/27 [==============================] - 0s 3ms/step - loss: 0.1141 - accuracy: 0.9532 - val_loss: 0.5321 - val_accuracy: 0.8409
# Epoch 70/100
# 27/27 [==============================] - 0s 4ms/step - loss: 0.1127 - accuracy: 0.9556 - val_loss: 0.5365 - val_accuracy: 0.8398
# Epoch 71/100
# 27/27 [==============================] - 0s 3ms/step - loss: 0.1125 - accuracy: 0.9570 - val_loss: 0.5355 - val_accuracy: 0.8374
# Epoch 72/100
# 27/27 [==============================] - 0s 3ms/step - loss: 0.1104 - accuracy: 0.9591 - val_loss: 0.5434 - val_accuracy: 0.8374
# Epoch 73/100
# 27/27 [==============================] - 0s 3ms/step - loss: 0.1077 - accuracy: 0.9594 - val_loss: 0.5359 - val_accuracy: 0.8421
# Epoch 74/100
# 27/27 [==============================] - 0s 4ms/step - loss: 0.1117 - accuracy: 0.9570 - val_loss: 0.5351 - val_accuracy: 0.8386
# Epoch 75/100
# 27/27 [==============================] - 0s 4ms/step - loss: 0.1103 - accuracy: 0.9558 - val_loss: 0.5456 - val_accuracy: 0.8363
# Epoch 76/100
# 27/27 [==============================] - 0s 3ms/step - loss: 0.1040 - accuracy: 0.9620 - val_loss: 0.5423 - val_accuracy: 0.8374
# Epoch 77/100
# 27/27 [==============================] - 0s 3ms/step - loss: 0.1043 - accuracy: 0.9614 - val_loss: 0.5448 - val_accuracy: 0.8374
# Epoch 78/100
# 27/27 [==============================] - 0s 4ms/step - loss: 0.1020 - accuracy: 0.9632 - val_loss: 0.5373 - val_accuracy: 0.8374
# Epoch 79/100
# 27/27 [==============================] - 0s 3ms/step - loss: 0.1010 - accuracy: 0.9643 - val_loss: 0.5415 - val_accuracy: 0.8386
# Epoch 80/100
# 27/27 [==============================] - 0s 3ms/step - loss: 0.1035 - accuracy: 0.9608 - val_loss: 0.5451 - val_accuracy: 0.8363
# Epoch 81/100
# 27/27 [==============================] - 0s 3ms/step - loss: 0.1014 - accuracy: 0.9614 - val_loss: 0.5614 - val_accuracy: 0.8386
# Epoch 82/100
# 27/27 [==============================] - 0s 4ms/step - loss: 0.0995 - accuracy: 0.9637 - val_loss: 0.5510 - val_accuracy: 0.8339
# Epoch 83/100
# 27/27 [==============================] - 0s 5ms/step - loss: 0.1041 - accuracy: 0.9594 - val_loss: 0.5585 - val_accuracy: 0.8339
# Epoch 84/100
# 27/27 [==============================] - 0s 4ms/step - loss: 0.0995 - accuracy: 0.9585 - val_loss: 0.5455 - val_accuracy: 0.8386
# Epoch 85/100
# 27/27 [==============================] - 0s 3ms/step - loss: 0.0974 - accuracy: 0.9617 - val_loss: 0.5539 - val_accuracy: 0.8374
# Epoch 86/100
# 27/27 [==============================] - 0s 3ms/step - loss: 0.0939 - accuracy: 0.9637 - val_loss: 0.5695 - val_accuracy: 0.8339
# Epoch 87/100
# 27/27 [==============================] - 0s 3ms/step - loss: 0.0997 - accuracy: 0.9635 - val_loss: 0.5571 - val_accuracy: 0.8363
# Epoch 88/100
# 27/27 [==============================] - 0s 3ms/step - loss: 0.0972 - accuracy: 0.9629 - val_loss: 0.5539 - val_accuracy: 0.8351
# Epoch 89/100
# 27/27 [==============================] - 0s 3ms/step - loss: 0.0969 - accuracy: 0.9643 - val_loss: 0.5566 - val_accuracy: 0.8339
# Epoch 90/100
# 27/27 [==============================] - 0s 3ms/step - loss: 0.0942 - accuracy: 0.9658 - val_loss: 0.5443 - val_accuracy: 0.8386
# Epoch 91/100
# 27/27 [==============================] - 0s 3ms/step - loss: 0.0957 - accuracy: 0.9640 - val_loss: 0.5657 - val_accuracy: 0.8327
# Epoch 92/100
# 27/27 [==============================] - 0s 3ms/step - loss: 0.0904 - accuracy: 0.9667 - val_loss: 0.5573 - val_accuracy: 0.8374
# Epoch 93/100
# 27/27 [==============================] - 0s 3ms/step - loss: 0.0929 - accuracy: 0.9640 - val_loss: 0.5500 - val_accuracy: 0.8363
# Epoch 94/100
# 27/27 [==============================] - 0s 3ms/step - loss: 0.0900 - accuracy: 0.9658 - val_loss: 0.5611 - val_accuracy: 0.8398
# Epoch 95/100
# 27/27 [==============================] - 0s 3ms/step - loss: 0.0869 - accuracy: 0.9696 - val_loss: 0.5605 - val_accuracy: 0.8374
# Epoch 96/100
# 27/27 [==============================] - 0s 3ms/step - loss: 0.0851 - accuracy: 0.9678 - val_loss: 0.5602 - val_accuracy: 0.8374
# Epoch 97/100
# 27/27 [==============================] - 0s 3ms/step - loss: 0.0869 - accuracy: 0.9667 - val_loss: 0.5531 - val_accuracy: 0.8339
# Epoch 98/100
# 27/27 [==============================] - 0s 3ms/step - loss: 0.0844 - accuracy: 0.9696 - val_loss: 0.5908 - val_accuracy: 0.8433
# Epoch 99/100
# 27/27 [==============================] - 0s 3ms/step - loss: 0.0859 - accuracy: 0.9675 - val_loss: 0.5827 - val_accuracy: 0.8363
# Epoch 100/100
# 27/27 [==============================] - 0s 3ms/step - loss: 0.0836 - accuracy: 0.9716 - val_loss: 0.5690 - val_accuracy: 0.8363

# %%
plt.plot(DNN_history.history['accuracy'], label='accuracy')
plt.plot(DNN_history.history['val_accuracy'], label='val_accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.ylim([0.5, 1])
plt.legend(loc='lower right')

test_loss, test_acc = DNN_model.evaluate(x_test, y_test, verbose=2)

print("test_acc:", test_acc)
# Out:
# 27/27 - 0s - loss: 0.5690 - accuracy: 0.8363 - 44ms/epoch - 2ms/step
# test_acc: 0.8362573385238647

# %% [markdown]
# # Save All Three Models

# %%
# CNN Model
CNN_2.save('CNNModel.2.0.h5')
# CNN Weights
CNN_2.save_weights('CNNWeights.2.0')

# SAE Model
SAE_model.save('SAEModel.2.0.h5')
# SAE Weights
SAE_model.save_weights('SAEWeights.2.0')

# DNN Model
DNN_model.save('DNNModel.2.0.h5')
# DNN Weights
DNN_model.save_weights('DNNWeights.2.0')
# Out:
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
